# %% [markdown]
# # How to extract tables from PDFs and from web pages
# ## use of packages:
# - tabula-py
# - pandas
# - matplotlib for plotting

# %%
from tabula import read_pdf
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## This imports a pdf file and extracts the values of the table:

# %%
df = read_pdf("n6.pdf");

# %% [markdown]
# ## If you just type df it will show a preview:

# %%
df
# Out:
#    Experiment  sn (MPa)   V (m/s)  a (m/s2)  Unnamed: 4  d (m)    mss  \
# 0        s042      40.0       6.5     65.00         NaN  14.93  0.052
# 1        s049      20.0         3     30.00         NaN      6  0.110
# 2        s050      20.0         3     30.00         NaN      6  0.105
# 3        s051      20.0         3      6.00         NaN      6  0.106
# 4        s052      20.0         3      3.00         NaN      6  0.120
# 5        s053      20.0         3      3.00         NaN      6  0.105
# 6        s054      20.0         3      6.00         NaN      6  0.111
# 7        s056      20.0         3     15.00         NaN      6  0.112
# 8        s058      20.0         3     15.00         NaN   7.81  0.101
# 9        s059      20.0         3     15.00         NaN      6  0.103
# 10       s062      40.0         3     30.00         NaN      6  0.075
# 11       s063      40.0         3      3.00         NaN      6  0.073
# ...

# %% [markdown]
# ## You can extract a single column by giving the column title as an argument.<br>Here we look at contents of *'V (m/s)'*:

# %%
print(df['V (m/s)'])
# Out:
# 0          6.5
# 1            3
# 2            3
# 3            3
# 4            3
# 5            3
# 6            3
# 7            3
# 8            3
# 9            3
# 10           3
# 11           3
# 12           3
# 13           3
# 14           5
# 15         6.5
# 16           1
# 17        1.14
# 18    10−3–0.8
# 19      10−3–3
# 20           3
# 21           3
# 22           3
# 23           3
# 24           3
# 25           3
# 26           3
# 27           3
# 28           3
# 29           3
# 30           3
# 31       3–0.3
# 32         1.3
# Name: V (m/s), dtype: object

# %% [markdown]
# ## Now let's plot the column of data *'mss'* (friction coefficient)<br>against the column of data *'sn (MPa)'*

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.plot(df['sn (MPa)'],df['mss'],'.r');plt.title('friction vs. normal stress')
print('hello')
# Out:
# <img src="data:image/png;base64,..." width="640">
# hello

# %% [markdown]
# ## Now let's put the contents of column 2 and column 5 in a proper *list*, and traspose it.
# We'll be using *iloc* to extract the line/column according to their indexes,  and np.transpose

# %%
sm=np.transpose([df.iloc[:,1],df.iloc[:,6]]).tolist();
print(sm);print(type(sm));
# Out:
# [[40.0, 0.052000000000000005], [20.0, 0.11], [20.0, 0.105], [20.0, 0.106], [20.0, 0.12], [20.0, 0.105], [20.0, 0.111], [20.0, 0.11199999999999999], [20.0, 0.10099999999999999], [20.0, 0.10300000000000001], [40.0, 0.075], [40.0, 0.073], [10.0, 0.147], [10.0, 0.175], [20.0, 0.10300000000000001], [20.0, 0.109], [20.0, 0.11199999999999999], [15.5, 0.145], [1.4, 0.662], [5.0, 0.258], [10.0, 0.145], [15.0, 0.126], [20.0, 0.106], [20.0, 0.105], [30.0, 0.08900000000000001], [5.0, 0.265], [30.0, 0.092], [2.5, 0.358], [7.5, 0.195], [50.0, 0.071], [1.0, 0.556], [0.7, 0.494], [10.0, 0.098]]
# <class 'list'>

# %% [markdown]
# ## We can now sort it by ascending first column value, and turn it in to a proper *array*.
# We're using np.array() to turn the list into an array (easier then to refer to indexed values).<br>
# We're using *sorted* to get ascending order. <br>
# We're using the *operator* library and *itemgetter* function to sort according to the fist column value as *key*.

# %%
import operator
sm=np.array(sorted(sm,key=operator.itemgetter(0)))
sm[:,0],sm[:,1]
# Out:
# (array([ 0.7,  1. ,  1.4,  2.5,  5. ,  5. ,  7.5, 10. , 10. , 10. , 10. ,
#         15. , 15.5, 20. , 20. , 20. , 20. , 20. , 20. , 20. , 20. , 20. ,
#         20. , 20. , 20. , 20. , 20. , 30. , 30. , 40. , 40. , 40. , 50. ]),
#  array([0.494, 0.556, 0.662, 0.358, 0.258, 0.265, 0.195, 0.147, 0.175,
#         0.145, 0.098, 0.126, 0.145, 0.11 , 0.105, 0.106, 0.12 , 0.105,
#         0.111, 0.112, 0.101, 0.103, 0.103, 0.109, 0.112, 0.106, 0.105,
#         0.089, 0.092, 0.052, 0.075, 0.073, 0.071]))

# %% [markdown]
# ## Now we can re-plot it as a series of connected points:

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.plot(sm[:,0],sm[:,1],'-r');plt.title('friction vs. normal stress');
plt.plot(sm[:,0],sm[:,1],'ob');plt.title('friction vs. normal stress');
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Let's try to fit an analytical curve to the data.
# We're fitting a function of the form
# $$
# y=c + \frac{a}{x+b}
# $$
# and we're looking for the bset fit values of constants $a,b,c$ in the least sqares sense.<br>
# We're using function *curve_fit* from module *scipy.optimize*. <br>
# We're defining initial values for the search as $(a,b,c)=(1,1,1)$.<br>
# We're plotting the curve $\pm$ one strandard error

# %%
from scipy.optimize import curve_fit
def myfunction(x,a,b,c):
    return c+ a/(x+b)
init_vals = [1, 1, 1]
[a,b,c], covar = curve_fit(myfunction, sm[:,0], sm[:,1], p0=init_vals)
err=np.sqrt(np.diag(covar))
print([a,b,c])
print(covar)
print(err)
# %matplotlib notebook
from matplotlib import pyplot as plt
plt.plot(sm[:,0],sm[:,1],'ob');plt.title('friction vs. normal stress');
plt.plot(sm[:,0],myfunction(sm[:,0],a,b,c),'-r',label='fit');
plt.plot(sm[:,0],myfunction(sm[:,0],a+err[0],b-err[1],c+err[2]),'--b',label='fit');
plt.plot(sm[:,0],myfunction(sm[:,0],a-err[0],b+err[1],c-err[2]),'--b',label='fit');
plt.fill_between(sm[:,0], 
                 myfunction(sm[:,0],a+err[0],b-err[1],c+err[2]), 
                 myfunction(sm[:,0],a-err[0],b+err[1],c-err[2]), 
                 facecolor="gray", alpha=0.15);
# Out:
# [1.8600013102845137, 2.5541586589749468, 0.022311669020346096]
# [[ 1.75227868e-01  2.95363291e-01 -7.43415092e-03]
#  [ 2.95363291e-01  5.24706327e-01 -1.19488098e-02]
#  [-7.43415092e-03 -1.19488098e-02  3.76635293e-04]]
# [0.41860228 0.72436616 0.01940709]
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Reading tables from html web pages
#
# let's look at this page with statistics on natural hazards:
#
# https://earthquake.usgs.gov/earthquakes/browse/stats.php
#
# There are five different tables; we import them all by default in a list called "toto.
# The tables will be identified by toto[0] to toto[5].
# Then we can extract information from the columns and lines of interest, and plot them (for example).

# %%
#toto=pd.read_html('https://earthquake.usgs.gov/earthquakes/browse/stats.php',header=None)
toto=pd.read_html('https://earthquake.usgs.gov/earthquakes/browse/stats.php')
toto[0]
# Out:
#          Magnitude  2000   2001  2002   2003    2004   2005  2006  2007  \
# 0             8.0+     1      1     0      1       2      1     2     4
# 1            7–7.9    14     15    13     14      14     10     9    14
# 2            6–6.9   146    121   127    140     141    140   142   178
# 3            5–5.9  1344   1224  1201   1203    1515   1693  1712  2074
# 4  EstimatedDeaths   231  21357  1685  33819  298101  87992  6605   708
#
#     2008  2009    2010   2011  2012  2013  2014  2015    2016    2017    2018
# 0      0     1       1      1     2     2     1     1     0.0     1.0     1.0
# 1     12    16      23     19    12    17    11    18    16.0     6.0    16.0
# 2    168   144     150    185   108   123   143   127   130.0   104.0   117.0
# 3   1768  1896    2209   2276  1401  1453  1574  1419  1550.0  1455.0  1674.0
# 4  88708  1790  226050  21942   689  1572   756  9624     NaN     NaN     NaN

# %%
toto[2]
# Out:
#          Magnitude   1990  1991  1992   1993  1994  1995  1996  1997  1998  \
# 0               8+      0     0     0      0     2     2     1     0     1
# 1            7–7.9     18    16    13     12    11    18    14    16    11
# 2            6–6.9    109    96   166    137   146   183   149   120   117
# 3            5–5.9   1617  1457  1498   1426  1542  1318  1222  1113   979
# 4  EstimatedDeaths  52056  3210  3920  10096  1634  7980   589  3069  9430
#
#     1999
# 0      0
# 1     18
# 2    116
# 3   1104
# 4  22662

# %% [markdown]
# We can now plot deaths vs. years

# %%
import matplotlib.ticker as ticker
fig,ax=plt.subplots()
ax.plot(toto[0].iloc[4].iloc[1:17],'^')
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

# %%
# combine table 1 and 3 together, extracting line 4, then plot all:
hlist1=toto[0].columns.get_values()
hlist2=toto[2].columns.get_values()
year1=[];deaths1=[];year2=[];deaths2=[]
for i in range(1,17): year1.append(int(hlist1[i]));
for i in range(1,17): deaths1.append(int(toto[0].iloc[4][i])); 
for i in range(1,10): year2.append(int(hlist2[i]));
for i in range(1,10): deaths2.append(int(toto[2].iloc[4][i]));
years=year2+year1;
deaths=deaths2+deaths1
fig,ax=plt.subplots();
ax.plot(years,deaths,'o');
ax.plot(years,deaths,'-');
